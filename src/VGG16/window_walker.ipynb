# %%
# %matplotlib widget

from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
import ipywidgets as widgets

import math
import numpy as np
import cv2
from tensorflow.keras.applications import vgg16
from tensorflow.keras.applications.vgg16 import preprocess_input

from vgg16_window_walker_lib_a import resize_frame, key_point_grid, next_pos_play, extract_window, paint_windows, MemoryGraph, build_graph

# %%
class VideoPatchBrowser:
    def __init__(self, video_file, ax1, ax2):
        with out:
            print("VideoPatchBrowser")
        self.orb = cv2.ORB_create(nfeatures=100000, fastThreshold=7)
        self.memory_graph = MemoryGraph(db_path, space='cosine', dim=512)
        self.model = vgg16.VGG16(weights="imagenet", include_top=False, input_shape=(32, 32, 3))
        self.cap = cv2.VideoCapture(video_file) 
        self.ax1 = ax1
        self.ax2 = ax2
        self.next_frame()


    def on_press(self, event):
        with out:
            print("on_press")
        self.next_frame()


    def on_click(self, event):
        if ax1 != event.inaxes:
            with out:
                print("outside")
            return

        pos = (event.ydata, event.xdata)

        with out:
            print("on_click", pos)
            
        self.next_patches(pos)


    def next_frame(self):
        if self.cap.isOpened():  
            ret, frame = self.cap.read() 

            if ret == True: 
                self.frame = frame
                self.update_ax1()
                return

        with out:
            print("No More Frames")


    def next_patches(pos):   
        print("show_patches")

        res_frame = resize_frame(self.frame)
        kp_grid = key_point_grid(self.orb, res_frame, stride)
        print("len(kp_grid)", len(kp_grid))

        grid_offset_x = ((self.frame.shape[0] - 32) % stride)/2.0 + 16
        grid_offset_y = ((self.frame.shape[1] - 32) % stride)/2.0 + 16
        g_pos = (int(math.floor((pos[0]-grid_offset_x)/stride)), int(math.floor((pos[1]-grid_offset_y)/stride)))

        print("g_pos", g_pos)
        path = []

        for i in range(playback_random_walk_length):
            g_pos, pos = next_pos_play(kp_grid, res_frame.shape, g_pos, stride)
            print("g_pos, pos", g_pos, pos)
            if g_pos is None:
                break
            path.append(pos)

        path = list(set(path))

        windows = np.array([extract_window(res_frame, p, window_size) for p in path])

        preprocess_input(windows)
        features = self.model.predict(windows)
        features = features.reshape((windows.shape[0], 512))
        
        print("windows.shape, feats.shape", windows.shape, features.shape)

        self.patches = self.build_patches(windows, features, path, self.frame.shape, self.memory_graph)
        self.update_ax2()


    def build_patches(path_windows, path_features, path_positions, frame_shape, memory_graph, window_size):
        
        frame = np.zeros((frame_shape[0], frame_shape[1], 3), np.uint8)

        paint_windows(path_positions, path_windows, frame, window_size, 0)

        # features, feature_dis, community_dis, k=30
        groups = list(memory_graph.search_group(path_features, .2, .2, 30))

        print("groups", groups)

        for i in range(len(groups)):
            group = list(groups[i])
            

            # node_ids = memory_graph.get_nodes(group)
            
            observation_ids = []
            for node_id in group:
                # print("node_id", node_id)
                integrated_observations = memory_graph.get_integrated_observations(node_id)
                observation_ids.extend(integrated_observations)
                predicted_observations = memory_graph.get_predicted_observations(node_id)
                observation_ids.extend(predicted_observations)

            windows = np.array([cv2.imread('../patches/patch'+str(observation_id)+'.png') for observation_id in observation_ids])

            observations = memory_graph.get_observations(observation_ids)

            positions = [(obs["y"], obs["x"]) for obs in observations]

            paint_windows(positions, windows, frame, window_size, i+1)
        
        return frame
        

    def update_ax1(self):
        self.ax1.cla()
        self.ax1.axis("off")
        self.ax1.imshow(cv2.cvtColor(self.frame, cv2.COLOR_BGR2RGB))
        

    def update_ax2(self):
        self.ax2.cla()
        self.ax2.axis("off")
        self.ax2.imshow(cv2.cvtColor(self.patches, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Play Video

# %%
stride = 16
window_size = 32
playback_random_walk_length = 10
# video_path = '../media/Tabletop Objects/videos/'
video_path = "../../media/Tabletop Objects/videos/001_apple.mp4"
db_path = "../../data/tabletop_objects_001_apple.db"
patch_dir = "../../patches"

# %%
video_file = "../../media/Tabletop Objects/videos/001_apple.mp4"
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,14), dpi= 100)

browser = VideoPatchBrowser(video_file, ax1, ax2)

fig.canvas.mpl_connect('button_release_event', browser.on_click)
fig.canvas.mpl_connect('key_press_event', browser.on_press)

fig.tight_layout()

ax1.axis("off")
ax2.axis("off")

out = widgets.Output()
display(out)

plt.show()

# %% [markdown]
# # Build Graph

# %%
build_graph(db_path, video_path, patch_dir, stride=stride, window_size=window_size)
# Out:
# Starting...
# MemoryGraph: loading nodes
# MemoryGraph: loading edges
# MemoryGraph: loaded 200 nodes, 0 edges
# Run 0
# frame 1 1
# res 200 near 65 iden 6 pred 0 acc 0 many 0
# frame 1 2
# res 0 near 69 iden 5 pred 0 acc 0 many 0
# frame 1 3
# res 3 near 78 iden 2 pred 46 acc 6 many 0
# frame 1 4
# res 2 near 82 iden 3 pred 69 acc 17 many 0
# frame 1 5
# res 2 near 80 iden 3 pred 75 acc 25 many 2
# frame 1 6
# res 5 near 94 iden 4 pred 76 acc 33 many 1
# frame 1 7
# res 5 near 89 iden 3 pred 88 acc 40 many 1
# frame 1 8
# res 3 near 96 iden 2 pred 86 acc 30 many 0
# frame 1 9
# res 1 near 97 iden 3 pred 94 acc 42 many 0
# frame 1 10
# res 3 near 85 iden 5 pred 95 acc 28 many 0
# frame 1 11
# res 1 near 88 iden 5 pred 84 acc 26 many 0
# frame 1 12
# res 1 near 78 iden 2 pred 86 acc 25 many 0
# frame 1 13
# res 2 near 85 iden 4 pred 77 acc 32 many 1
# frame 1 14
# res 3 near 88 iden 3 pred 83 acc 35 many 2
# frame 1 15
# res 3 near 86 iden 4 pred 83 acc 32 many 2
# frame 1 16
# res 6 near 93 iden 5 pred 83 acc 37 many 4
# frame 1 17
# res 4 near 84 iden 3 pred 89 acc 35 many 4
# frame 1 18
# res 6 near 88 iden 3 pred 79 acc 34 many 0
# frame 1 19
# res 1 near 97 iden 4 pred 87 acc 34 many 3
# frame 1 20
# res 3 near 100 iden 0 pred 94 acc 34 many 4
# frame 1 21
# res 6 near 89 iden 2 pred 94 acc 30 many 3
# frame 1 22
# res 6 near 102 iden 3 pred 86 acc 32 many 0
# frame 1 23
# res 3 near 108 iden 3 pred 101 acc 36 many 2
# frame 1 24
# res 2 near 93 iden 0 pred 106 acc 29 many 0
# frame 1 25
# res 0 near 104 iden 2 pred 93 acc 30 many 1
# frame 1 26
# res 2 near 103 iden 2 pred 102 acc 27 many 0
# frame 1 27
# res 1 near 110 iden 4 pred 102 acc 33 many 3
# frame 1 28
# res 7 near 103 iden 4 pred 106 acc 30 many 1
# frame 1 29
# res 2 near 100 iden 6 pred 101 acc 31 many 1
# frame 1 30
# res 2 near 83 iden 6 pred 98 acc 23 many 0
# frame 1 31
# res 2 near 82 iden 7 pred 83 acc 18 many 1
# frame 1 32
# res 3 near 99 iden 9 pred 80 acc 25 many 2
# frame 1 33
# res 4 near 92 iden 9 pred 97 acc 24 many 3
# frame 1 34
# res 6 near 101 iden 4 pred 86 acc 24 many 0
# frame 1 35
# res 2 near 101 iden 4 pred 101 acc 28 many 1
# frame 1 36
# res 2 near 96 iden 5 pred 99 acc 28 many 0
# frame 1 37
# res 2 near 97 iden 6 pred 95 acc 29 many 0
# frame 1 38
# res 2 near 83 iden 4 pred 97 acc 25 many 1
# frame 1 39
# res 3 near 94 iden 4 pred 82 acc 23 many 0
# frame 1 40
# res 3 near 85 iden 4 pred 93 acc 20 many 0
# frame 1 41
# res 0 near 57 iden 9 pred 85 acc 14 many 0
# frame 1 42
# res 0 near 83 iden 11 pred 57 acc 14 many 0
# frame 1 43
# res 3 near 65 iden 7 pred 82 acc 13 many 0
# frame 1 44
# res 1 near 78 iden 5 pred 65 acc 19 many 0
# frame 1 45
# res 2 near 76 iden 15 pred 78 acc 15 many 0
# frame 1 46
# res 1 near 79 iden 8 pred 75 acc 18 many 0
# frame 1 47
# res 3 near 85 iden 7 pred 79 acc 12 many 0
# frame 1 48
# res 1 near 84 iden 6 pred 85 acc 11 many 0
# frame 1 49
# res 4 near 82 iden 8 pred 81 acc 14 many 0
# frame 1 50
# res 1 near 86 iden 6 pred 82 acc 14 many 0
# frame 1 51
# res 2 near 88 iden 1 pred 85 acc 15 many 0
# frame 1 52
# res 4 near 91 iden 6 pred 87 acc 14 many 0
# frame 1 53
# res 0 near 101 iden 8 pred 91 acc 17 many 0
# frame 1 54
# res 1 near 105 iden 7 pred 100 acc 18 many 0
# frame 1 55
# res 2 near 92 iden 5 pred 103 acc 17 many 0
# frame 1 56
# res 3 near 72 iden 6 pred 92 acc 11 many 0
# frame 1 57
# res 5 near 116 iden 6 pred 71 acc 12 many 0
# frame 1 58
# res 3 near 109 iden 7 pred 114 acc 27 many 0
# frame 1 59
# res 1 near 119 iden 4 pred 108 acc 26 many 0
# frame 1 60
# res 2 near 122 iden 3 pred 118 acc 27 many 0
# frame 1 61
# res 3 near 103 iden 2 pred 119 acc 20 many 0
# frame 1 62
# res 3 near 59 iden 3 pred 101 acc 15 many 0
# frame 1 63
# res 3 near 70 iden 4 pred 59 acc 14 many 0
# frame 1 64
# res 1 near 64 iden 1 pred 69 acc 17 many 0
# frame 1 65
# res 3 near 82 iden 1 pred 64 acc 21 many 0
# frame 1 66
# res 2 near 100 iden 4 pred 82 acc 19 many 0
# frame 1 67
# res 1 near 75 iden 4 pred 100 acc 18 many 0
# frame 1 68
# res 2 near 91 iden 3 pred 74 acc 20 many 0
# frame 1 69
# res 1 near 95 iden 5 pred 91 acc 16 many 1
# frame 1 70
# res 2 near 106 iden 5 pred 93 acc 24 many 0
# frame 1 71
# res 1 near 113 iden 3 pred 105 acc 21 many 0
# frame 1 72
# res 0 near 103 iden 1 pred 113 acc 28 many 0
# frame 1 73
# res 2 near 79 iden 7 pred 103 acc 26 many 0
# frame 1 74
# res 1 near 60 iden 6 pred 79 acc 13 many 0
# frame 1 75
# res 2 near 51 iden 5 pred 58 acc 11 many 0
# frame 1 76
# res 1 near 63 iden 6 pred 50 acc 10 many 0
# frame 1 77
# res 3 near 77 iden 3 pred 62 acc 12 many 0
# frame 1 78
# res 1 near 89 iden 4 pred 77 acc 15 many 0
# frame 1 79
# res 2 near 74 iden 3 pred 88 acc 15 many 0
# frame 1 80
# res 2 near 82 iden 2 pred 73 acc 17 many 0
# frame 1 81
# res 2 near 65 iden 1 pred 82 acc 17 many 0
# frame 1 82
# res 2 near 54 iden 6 pred 65 acc 4 many 1
# frame 1 83
# res 1 near 76 iden 6 pred 53 acc 10 many 0
# frame 1 84
# res 7 near 75 iden 5 pred 75 acc 13 many 0
# frame 1 85
# res 5 near 38 iden 5 pred 74 acc 4 many 0
# frame 1 86
# res 3 near 61 iden 8 pred 37 acc 5 many 0
# frame 1 87
# res 3 near 38 iden 8 pred 60 acc 8 many 0
# frame 1 88
# res 0 near 43 iden 5 pred 38 acc 5 many 0
# frame 1 89
# res 0 near 63 iden 5 pred 43 acc 7 many 0
# frame 1 90
# res 2 near 70 iden 5 pred 63 acc 10 many 0
# frame 1 91
# res 1 near 84 iden 7 pred 69 acc 16 many 0
# frame 1 92
# res 2 near 52 iden 7 pred 83 acc 11 many 0
# frame 1 93
# res 0 near 61 iden 2 pred 52 acc 11 many 0
# frame 1 94
# res 5 near 85 iden 7 pred 59 acc 12 many 0
# frame 1 95
# res 2 near 61 iden 2 pred 84 acc 16 many 1
# frame 1 96
# res 4 near 71 iden 6 pred 59 acc 11 many 0
# frame 1 97
# res 1 near 81 iden 6 pred 70 acc 16 many 0
# frame 1 98
# res 3 near 92 iden 5 pred 79 acc 10 many 0
# frame 1 99
# res 0 near 91 iden 2 pred 92 acc 13 many 0
# frame 1 100
# res 1 near 73 iden 2 pred 91 acc 12 many 0
# frame 1 101
# res 2 near 73 iden 3 pred 72 acc 12 many 0
# frame 1 102
# res 3 near 80 iden 4 pred 71 acc 10 many 0
# frame 1 103
# res 2 near 81 iden 0 pred 80 acc 10 many 0
# frame 1 104
# res 0 near 91 iden 3 pred 81 acc 11 many 0
# frame 1 105
# res 3 near 97 iden 1 pred 89 acc 15 many 0
# frame 1 106
# res 1 near 96 iden 3 pred 96 acc 14 many 0
# frame 1 107
# res 4 near 95 iden 1 pred 94 acc 8 many 0
# frame 1 108
# res 4 near 111 iden 5 pred 91 acc 15 many 0
# frame 1 109
# res 1 near 106 iden 4 pred 110 acc 15 many 0
# frame 1 110
# res 3 near 111 iden 3 pred 105 acc 15 many 0
# frame 1 111
# res 1 near 105 iden 1 pred 111 acc 18 many 0
# frame 1 112
# res 0 near 104 iden 2 pred 105 acc 19 many 1
# frame 1 113
# res 3 near 105 iden 3 pred 101 acc 11 many 0
# frame 1 114
# res 2 near 102 iden 6 pred 103 acc 15 many 1
# frame 1 115
# res 5 near 97 iden 2 pred 100 acc 18 many 0
# frame 1 116
# res 2 near 87 iden 6 pred 95 acc 14 many 0
# frame 1 117
# res 1 near 91 iden 4 pred 86 acc 12 many 1
# frame 1 118
# res 4 near 79 iden 6 pred 90 acc 5 many 0
# frame 1 119
# res 1 near 78 iden 7 pred 79 acc 16 many 0
# frame 1 120
# res 2 near 83 iden 3 pred 77 acc 9 many 0
# frame 1 121
# res 3 near 83 iden 0 pred 83 acc 10 many 0
# frame 1 122
# res 2 near 77 iden 1 pred 83 acc 11 many 0
# frame 1 123
# res 4 near 75 iden 6 pred 77 acc 9 many 0
# frame 1 124
# res 2 near 100 iden 5 pred 75 acc 8 many 0
# frame 1 125
# res 5 near 69 iden 1 pred 96 acc 11 many 0
# frame 1 126
# res 1 near 81 iden 3 pred 69 acc 7 many 0
# frame 1 127
# res 5 near 74 iden 3 pred 79 acc 13 many 0
# frame 1 128
# res 0 near 88 iden 3 pred 74 acc 15 many 0
# frame 1 129
# res 2 near 89 iden 5 pred 85 acc 11 many 1
# frame 1 130
# res 5 near 86 iden 2 pred 86 acc 14 many 0
# frame 1 131
# res 3 near 83 iden 3 pred 85 acc 10 many 0
# frame 1 132
# res 3 near 85 iden 2 pred 82 acc 10 many 0
# frame 1 133
# res 0 near 84 iden 4 pred 85 acc 10 many 1
# frame 1 134
# res 2 near 97 iden 2 pred 83 acc 17 many 0
# frame 1 135
# res 1 near 85 iden 3 pred 96 acc 12 many 0
# frame 1 136
# res 1 near 73 iden 4 pred 85 acc 9 many 0
# frame 1 137
# res 3 near 84 iden 3 pred 72 acc 9 many 0
# frame 1 138
# res 4 near 98 iden 2 pred 83 acc 13 many 0
# frame 1 139
# res 1 near 94 iden 3 pred 97 acc 18 many 0
# frame 1 140
# res 3 near 99 iden 2 pred 91 acc 12 many 0
# frame 1 141
# res 1 near 97 iden 3 pred 98 acc 13 many 0
# frame 1 142
# res 2 near 86 iden 1 pred 96 acc 15 many 1
# frame 1 143
# res 3 near 94 iden 3 pred 83 acc 12 many 0
# frame 1 144
# res 2 near 91 iden 2 pred 92 acc 18 many 0
# frame 1 145
# res 3 near 74 iden 6 pred 89 acc 11 many 0
# frame 1 146
# res 1 near 75 iden 5 pred 74 acc 17 many 0
# frame 1 147
# res 2 near 90 iden 5 pred 74 acc 12 many 0
# frame 1 148
# res 0 near 87 iden 5 pred 90 acc 16 many 0
# frame 1 149
# res 4 near 79 iden 4 pred 86 acc 12 many 0
# frame 1 150
# res 2 near 69 iden 14 pred 78 acc 8 many 0
# frame 1 151
# res 2 near 87 iden 7 pred 68 acc 11 many 0
# frame 1 152
# res 3 near 91 iden 7 pred 86 acc 14 many 0
# frame 1 153
# res 2 near 89 iden 11 pred 89 acc 14 many 0
# frame 1 154
# res 4 near 88 iden 9 pred 88 acc 16 many 0
# frame 1 155
# res 2 near 100 iden 5 pred 88 acc 18 many 0
# frame 1 156
# res 0 near 86 iden 11 pred 100 acc 12 many 0
# frame 1 157
# res 1 near 89 iden 11 pred 86 acc 18 many 0
# frame 1 158
# res 1 near 74 iden 7 pred 88 acc 14 many 0
# frame 1 159
# res 2 near 86 iden 6 pred 74 acc 14 many 1
# frame 1 160
# res 1 near 86 iden 6 pred 85 acc 19 many 0
# frame 1 161
# res 1 near 74 iden 7 pred 86 acc 10 many 0
# frame 1 162
# res 3 near 95 iden 5 pred 73 acc 16 many 0
# frame 1 163
# res 2 near 98 iden 2 pred 94 acc 15 many 0
# frame 1 164
# res 2 near 75 iden 2 pred 97 acc 14 many 0
# frame 1 165
# res 3 near 82 iden 3 pred 74 acc 10 many 1
# frame 1 166
# res 2 near 84 iden 5 pred 81 acc 10 many 0
# frame 1 167
# res 2 near 77 iden 2 pred 84 acc 9 many 0
# frame 1 168
# res 1 near 81 iden 4 pred 77 acc 12 many 0
# frame 1 169
# res 3 near 70 iden 5 pred 80 acc 11 many 0
# frame 1 170
# res 1 near 87 iden 3 pred 69 acc 12 many 0
# frame 1 171
# res 1 near 76 iden 6 pred 86 acc 10 many 0
# frame 1 172
# res 3 near 82 iden 4 pred 75 acc 10 many 1
# frame 1 173
# res 2 near 89 iden 8 pred 81 acc 11 many 0
# frame 1 174
# res 2 near 69 iden 4 pred 89 acc 13 many 3
# frame 1 175
# res 5 near 82 iden 7 pred 65 acc 7 many 0
# frame 1 176
# res 1 near 79 iden 1 pred 82 acc 7 many 0
# frame 1 177
# res 2 near 83 iden 5 pred 78 acc 8 many 0
# frame 1 178
# res 4 near 79 iden 10 pred 83 acc 9 many 0
# frame 1 179
# res 3 near 64 iden 10 pred 78 acc 5 many 0
# frame 1 180
# res 2 near 70 iden 5 pred 64 acc 10 many 2
# frame 1 181
# res 7 near 60 iden 9 pred 65 acc 6 many 0
# frame 1 182
# res 2 near 76 iden 7 pred 59 acc 5 many 0
# frame 1 183
# res 2 near 64 iden 3 pred 75 acc 11 many 0
# frame 1 184
# res 1 near 71 iden 7 pred 64 acc 3 many 1
# frame 1 185
# res 2 near 72 iden 9 pred 70 acc 8 many 0
# frame 1 186
# res 0 near 77 iden 8 pred 72 acc 4 many 0
# frame 1 187
# res 1 near 78 iden 3 pred 77 acc 11 many 0
# frame 1 188
# res 2 near 79 iden 2 pred 77 acc 15 many 1
# frame 1 189
# res 3 near 82 iden 3 pred 77 acc 9 many 0
# frame 1 190
# res 3 near 78 iden 6 pred 82 acc 12 many 0
# frame 1 191
# res 3 near 69 iden 4 pred 77 acc 12 many 0
# frame 1 192
# res 1 near 82 iden 3 pred 68 acc 17 many 0
# frame 1 193
# res 3 near 84 iden 3 pred 81 acc 21 many 1
# frame 1 194
# res 5 near 84 iden 4 pred 81 acc 15 many 0
# frame 1 195
# res 3 near 76 iden 3 pred 83 acc 12 many 0
# frame 1 196
# res 2 near 76 iden 5 pred 76 acc 10 many 1
# frame 1 197
# res 3 near 91 iden 6 pred 74 acc 13 many 1
# frame 1 198
# res 4 near 92 iden 6 pred 88 acc 18 many 0
# frame 1 199
# res 1 near 84 iden 5 pred 91 acc 19 many 0
# frame 1 200
# res 3 near 48 iden 3 pred 82 acc 11 many 0
# frame 1 201
# res 3 near 58 iden 5 pred 46 acc 6 many 0
# frame 1 202
# res 2 near 70 iden 8 pred 58 acc 8 many 0
# frame 1 203
# res 3 near 53 iden 10 pred 68 acc 10 many 3
# frame 1 204
# res 4 near 45 iden 8 pred 49 acc 7 many 0
# frame 1 205
# res 1 near 73 iden 7 pred 44 acc 10 many 0
# frame 1 206
# res 4 near 83 iden 10 pred 72 acc 13 many 1
# frame 1 207
# res 2 near 70 iden 14 pred 81 acc 13 many 0
# frame 1 208
# res 4 near 86 iden 12 pred 70 acc 19 many 0
# frame 1 209
# res 1 near 101 iden 13 pred 84 acc 14 many 0
# frame 1 210
# res 0 near 90 iden 12 pred 101 acc 20 many 0
# frame 1 211
# res 1 near 44 iden 9 pred 90 acc 3 many 0
# frame 1 212
# res 2 near 66 iden 6 pred 44 acc 3 many 1
# frame 1 213
# res 3 near 68 iden 3 pred 64 acc 7 many 0
# frame 1 214
# res 3 near 56 iden 5 pred 67 acc 5 many 0
# frame 1 215
# res 0 near 73 iden 1 pred 56 acc 8 many 0
# frame 1 216
# res 3 near 77 iden 7 pred 72 acc 8 many 0
# frame 1 217
# res 0 near 62 iden 8 pred 77 acc 7 many 0
# frame 1 218
# res 2 near 88 iden 1 pred 61 acc 10 many 0
# frame 1 219
# res 2 near 98 iden 6 pred 88 acc 17 many 1
# frame 1 220
# res 1 near 85 iden 9 pred 97 acc 14 many 0
# frame 1 221
# res 2 near 56 iden 10 pred 85 acc 3 many 1
# frame 1 222
# res 3 near 80 iden 9 pred 54 acc 8 many 0
# frame 1 223
# res 1 near 85 iden 8 pred 79 acc 6 many 0
# frame 1 224
# res 1 near 80 iden 6 pred 84 acc 7 many 0
# frame 1 225
# res 4 near 99 iden 5 pred 80 acc 13 many 0
# frame 1 226
# res 0 near 88 iden 8 pred 99 acc 13 many 0
# frame 1 227
# res 2 near 87 iden 12 pred 88 acc 4 many 0
# frame 1 228
# res 1 near 98 iden 10 pred 86 acc 11 many 0
# frame 1 229
# res 0 near 97 iden 12 pred 98 acc 11 many 0
# frame 1 230
# res 4 near 104 iden 14 pred 96 acc 18 many 0
# frame 1 231
# res 1 near 86 iden 11 pred 103 acc 15 many 0
# frame 1 232
# res 3 near 80 iden 6 pred 85 acc 10 many 0
# frame 1 233
# res 1 near 79 iden 3 pred 80 acc 8 many 0
# frame 1 234
# res 2 near 106 iden 5 pred 78 acc 14 many 1
# frame 1 235
# res 4 near 93 iden 7 pred 104 acc 12 many 0
# frame 1 236
# res 4 near 86 iden 9 pred 91 acc 9 many 0
# frame 1 237
# res 1 near 76 iden 5 pred 85 acc 9 many 0
# frame 1 238
# res 5 near 101 iden 9 pred 75 acc 9 many 0
# frame 1 239
# res 6 near 92 iden 5 pred 98 acc 21 many 0
# frame 1 240
# res 2 near 109 iden 10 pred 90 acc 23 many 0
# frame 1 241
# res 1 near 110 iden 10 pred 108 acc 29 many 0
# frame 1 242
# res 4 near 91 iden 16 pred 107 acc 16 many 0
# frame 1 243
# res 5 near 108 iden 11 pred 90 acc 17 many 0
# frame 1 244
# res 0 near 126 iden 10 pred 108 acc 45 many 0
# frame 1 245
# res 5 near 95 iden 15 pred 123 acc 22 many 0
# frame 1 246
# res 6 near 113 iden 15 pred 92 acc 15 many 1
# frame 1 247
# res 3 near 113 iden 15 pred 111 acc 22 many 2
# frame 1 248
# res 4 near 125 iden 12 pred 110 acc 26 many 1
# frame 1 249
# res 1 near 127 iden 11 pred 124 acc 37 many 0
# frame 1 250
# res 1 near 122 iden 15 pred 126 acc 42 many 1
# frame 1 251
# res 4 near 118 iden 10 pred 119 acc 25 many 0
# frame 1 252
# res 0 near 120 iden 15 pred 118 acc 33 many 0
# frame 1 253
# res 1 near 120 iden 20 pred 119 acc 28 many 0
# frame 1 254
# res 2 near 102 iden 25 pred 120 acc 26 many 0
# frame 1 255
# res 2 near 104 iden 19 pred 101 acc 22 many 0
# frame 1 256
# res 3 near 118 iden 22 pred 102 acc 26 many 1
# frame 1 257
# res 1 near 124 iden 23 pred 117 acc 27 many 0
# frame 1 258
# res 1 near 110 iden 24 pred 124 acc 21 many 0
# frame 1 259
# res 1 near 99 iden 14 pred 110 acc 26 many 0
# frame 1 260
# res 1 near 100 iden 11 pred 99 acc 12 many 0
# frame 1 261
# res 2 near 105 iden 10 pred 100 acc 18 many 1
# frame 1 262
# res 6 near 94 iden 7 pred 101 acc 20 many 1
# frame 1 263
# res 3 near 70 iden 4 pred 92 acc 8 many 1
# frame 1 264
# res 3 near 87 iden 5 pred 68 acc 10 many 1
# frame 1 265
# res 2 near 80 iden 3 pred 85 acc 10 many 0
# frame 1 266
# res 2 near 79 iden 9 pred 80 acc 14 many 0
# frame 1 267
# res 2 near 91 iden 0 pred 79 acc 13 many 0
# frame 1 268
# res 3 near 100 iden 4 pred 89 acc 14 many 0
# frame 1 269
# res 3 near 102 iden 1 pred 98 acc 12 many 0
# frame 1 270
